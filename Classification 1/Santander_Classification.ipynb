# %% [markdown]
# # Customer Satisfaction Classificaiton Happy or Not?

# %%
import pandas as pd 
import numpy as np

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
df = pd.concat([train_df, test_df], ignore_index=True)

# %%
df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0     0.0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1     0.0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2     0.0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3     0.0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4     0.0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7   var_8   var_9  var_10   var_11   var_12   var_13  var_14  \
# 0  18.6266 -4.9200  5.7470  2.9252   3.1821  14.0137   0.5745  8.7989
# 1  16.5338  3.1468  8.0851 -0.4032   8.0585  14.0239   8.4135  5.4345
# 2  14.6155 -4.9193  5.9525 -0.3249 -11.2648  14.1929   7.3124  7.5244
# 3  14.9250 -5.8609  8.2450  2.3061   2.8102  13.8463  11.9704  6.4569
# 4  19.2514  6.2654  7.6784 -9.4458 -12.1419  13.8481   7.8895  7.7894
#
# ...

# %%
df.shape
# Out:
# (400000, 202)

# %%
df.isna().sum()
# Out:
# ID_code         0
# target     200000
# var_0           0
# var_1           0
# var_2           0
# var_3           0
# var_4           0
# var_5           0
# var_6           0
# var_7           0
# var_8           0
# var_9           0
# var_10          0
# var_11          0
# var_12          0
# var_13          0
# var_14          0
# var_15          0
# var_16          0
# var_17          0
# var_18          0
# var_19          0
# var_20          0
# var_21          0
# var_22          0
# var_23          0
# var_24          0
# var_25          0
# var_26          0
# var_27          0
# var_28          0
# var_29          0
# var_30          0
# var_31          0
# var_32          0
# var_33          0
# var_34          0
# var_35          0
# var_36          0
# var_37          0
# var_38          0
# var_39          0
# var_40          0
# var_41          0
# var_42          0
# var_43          0
# var_44          0
# var_45          0
# var_46          0
# var_47          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400000 entries, 0 to 399999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(201), object(1)
# memory usage: 616.5+ MB

# %%
df = df.drop('ID_code',axis=1)

# %%
#df = df.sample(50000).reset_index(drop=True)

# %%
df.head()
# Out:
#    target    var_0   var_1    var_2   var_3    var_4   var_5   var_6    var_7  \
# 0     0.0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187  18.6266
# 1     0.0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208  16.5338
# 2     0.0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427  14.6155
# 3     0.0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428  14.9250
# 4     0.0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405  19.2514
#
#     var_8   var_9  var_10   var_11   var_12   var_13  var_14   var_15  \
# 0 -4.9200  5.7470  2.9252   3.1821  14.0137   0.5745  8.7989  14.5691
# 1  3.1468  8.0851 -0.4032   8.0585  14.0239   8.4135  5.4345  13.7003
# 2 -4.9193  5.9525 -0.3249 -11.2648  14.1929   7.3124  7.5244  14.6472
# 3 -5.8609  8.2450  2.3061   2.8102  13.8463  11.9704  6.4569  14.8372
# 4  6.2654  7.6784 -9.4458 -12.1419  13.8481   7.8895  7.7894  15.0553
#
#     var_16   var_17   var_18   var_19   var_20   var_21   var_22  var_23  \
# ...

# %%
test_df = df[df['target'].isnull()] #null rows 

df = df[df['target'].notnull()]

# %%
num_duplicates_after = df.duplicated().sum()
print(f"Number of duplicate rows to clean: {num_duplicates_after}")
# Out:
# Number of duplicate rows to clean: 0

# %% [markdown]
# ### The assess_linearity function assesses whether a linear or polynomial regression model better fits the relationship between each feature and the target variable, providing insights into the nature of those relationships.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

def assess_linearity(df, target_column):
    results = []
    
    for column in df.columns:
        if column != target_column:
            X = df[[column]]
            y = df[target_column]
            
            # Linear Regression
            linear_model = LinearRegression()
            linear_model.fit(X, y)
            y_pred_linear = linear_model.predict(X)
            r2_linear = r2_score(y, y_pred_linear)
            
            # Polynomial Regression (degree 2)
            poly = PolynomialFeatures(degree=2)
            X_poly = poly.fit_transform(X)
            poly_model = LinearRegression()
            poly_model.fit(X_poly, y)
            y_pred_poly = poly_model.predict(X_poly)
            r2_poly = r2_score(y, y_pred_poly)
            
            # Store results
            results.append({
                'Feature': column,
                'R² Linear': r2_linear,
                'R² Polynomial': r2_poly,
                'Better Model': 'Linear' if r2_linear >= r2_poly else 'Polynomial'
            })
    
    return pd.DataFrame(results)

linearity_results = assess_linearity(df, 'target')

# %%
linearity_results.head()
# Out:
#   Feature  R² Linear  R² Polynomial Better Model
# 0   var_0   0.002745       0.004146   Polynomial
# 1   var_1   0.002534       0.003349   Polynomial
# 2   var_2   0.003121       0.004528   Polynomial
# 3   var_3   0.000122       0.000186   Polynomial
# 4   var_4   0.000119       0.000213   Polynomial

# %%
linearity_results['Better Model'].value_counts()
# Out:
# Better Model
# Polynomial    200
# Name: count, dtype: int64

# %% [markdown]
# ## we can see that all of our features represents non-inear distribution

# %%
x = df.drop('target',axis=1)
y = df['target']

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE

print("Class distribution before oversampling:")
print(Counter(y))
# Out:
# Class distribution before oversampling:
# Counter({0.0: 179902, 1.0: 20098})

# %% [markdown]
# ## there is imbalance in the dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(14, 8))
plt.scatter(x.iloc[:, 0], x.iloc[:, 1], c=y, s=50, edgecolor='k');

# %%
smote = SMOTE()
x_resampled, y_resampled = smote.fit_resample(x, y)

# %%
print("\nClass distribution after oversampling:")
print(Counter(y_resampled))
# Out:
# Class distribution after oversampling:
# Counter({0.0: 179902, 1.0: 179902})

# %%
plt.figure(figsize=(14, 8))
plt.scatter(x_resampled.iloc[:, 0], x_resampled.iloc[:, 1], c=y_resampled, s=50, edgecolor='k');

# %% [markdown]
# ## we fixed the balance issue with SMOTE

# %%
x = x_resampled
y = y_resampled

# %% [markdown]
# ### The QuantileTransformer transforms the data to follow a normal distribution. It achieves this by adjusting the data based on the ranks of the values, making it more uniform and reducing the influence of outliers.
#     This is especially useful when we want to ensure that our data is well-suited for models that perform better with normally distributed inputs.

# %%
from sklearn.preprocessing import QuantileTransformer

scaler = QuantileTransformer(output_distribution='normal', random_state=42)
scaled_df = scaler.fit_transform(x)

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam, SGD

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(scaled_df.shape[1],))) # x.shape[1]=19

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
model.fit(scaled_df, y, epochs=50, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/50
# 4498/4498 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.6946 - loss: 0.5916 - val_accuracy: 0.8530 - val_loss: 0.3319
# Epoch 2/50
# 4498/4498 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.8346 - loss: 0.3828 - val_accuracy: 0.8600 - val_loss: 0.3194
# Epoch 3/50
# 4498/4498 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8461 - loss: 0.3595 - val_accuracy: 0.8685 - val_loss: 0.3017
# Epoch 4/50
# 4498/4498 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8557 - loss: 0.3390 - val_accuracy: 0.8766 - val_loss: 0.2797
# Epoch 5/50
# 4498/4498 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8616 - loss: 0.3267 - val_accuracy: 0.8783 - val_loss: 0.2672
# Epoch 6/50
# 4498/4498 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8683 - loss: 0.3152 - val_accuracy: 0.8868 - val_loss: 0.2460
# Epoch 7/50
# 4498/4498 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8729 - loss: 0.3042 - val_accuracy: 0.8823 - val_loss: 0.2569
# Epoch 8/50
# ...

# %%
model.save('my_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#encoder.save('encoder_model.h5')

# %%
import pickle

# %%
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
with open('scaler.pkl', 'rb') as file:
    scaler_object = pickle.load(file)

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('my_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ### Making a Prediction

# %%
test_df.head().reset_index(drop=True)
# Out:
#    target    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0     NaN  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1     NaN   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2     NaN   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3     NaN   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4     NaN  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8   var_9  var_10  var_11   var_12   var_13   var_14  \
# 0  18.2675  2.1337  8.8100 -2.0248 -4.3554  13.9696   0.3458   7.5408
# 1  18.6316 -4.4131  5.9739 -1.3809 -0.3310  14.1129   2.5667   5.4988
# 2  20.2537  1.5233  8.3442 -4.7057 -3.0422  13.6751   3.8183  10.8535
# 3  20.5660  3.3755  7.4578  0.0095 -5.0659  14.0526  13.5010   8.7660
# 4  10.6048  2.9890  7.1437  5.1025 -3.2827  14.1013   8.9672   4.7276
#
#     var_15   var_16   var_17   var_18   var_19   var_20   var_21  var_22  \
# ...

# %%
x = test_df.drop('target',axis=1)
y = test_df[['target']]

# %%
scaled_df = scaler_object.fit_transform(x)

# %%
predictions = model.predict(scaled_df)

#predicted_classes = np.argmax(predictions, axis=1)
# Out:
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 3s 466us/step

# %%
test_df['predicted_values'] = predictions

# %%
test_df.head()
# Out:
#         target    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 200000     NaN  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 200001     NaN   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 200002     NaN   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 200003     NaN   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 200004     NaN  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#           var_7   var_8   var_9  var_10  var_11   var_12   var_13   var_14  \
# 200000  18.2675  2.1337  8.8100 -2.0248 -4.3554  13.9696   0.3458   7.5408
# 200001  18.6316 -4.4131  5.9739 -1.3809 -0.3310  14.1129   2.5667   5.4988
# 200002  20.2537  1.5233  8.3442 -4.7057 -3.0422  13.6751   3.8183  10.8535
# 200003  20.5660  3.3755  7.4578  0.0095 -5.0659  14.0526  13.5010   8.7660
# 200004  10.6048  2.9890  7.1437  5.1025 -3.2827  14.1013   8.9672   4.7276
#
# ...

# %%
test_df = test_df.reset_index(drop=True)

# %%
test_df_id = pd.read_csv('test.csv')

# %%
test_df_id.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8   var_9  var_10  var_11   var_12   var_13   var_14  \
# 0  18.2675  2.1337  8.8100 -2.0248 -4.3554  13.9696   0.3458   7.5408
# 1  18.6316 -4.4131  5.9739 -1.3809 -0.3310  14.1129   2.5667   5.4988
# 2  20.2537  1.5233  8.3442 -4.7057 -3.0422  13.6751   3.8183  10.8535
# 3  20.5660  3.3755  7.4578  0.0095 -5.0659  14.0526  13.5010   8.7660
# 4  10.6048  2.9890  7.1437  5.1025 -3.2827  14.1013   8.9672   4.7276
#
#     var_15   var_16   var_17   var_18   var_19   var_20   var_21  var_22  \
# ...

# %%
test_df.head()
# Out:
#    target    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0     NaN  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1     NaN   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2     NaN   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3     NaN   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4     NaN  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8   var_9  var_10  var_11   var_12   var_13   var_14  \
# 0  18.2675  2.1337  8.8100 -2.0248 -4.3554  13.9696   0.3458   7.5408
# 1  18.6316 -4.4131  5.9739 -1.3809 -0.3310  14.1129   2.5667   5.4988
# 2  20.2537  1.5233  8.3442 -4.7057 -3.0422  13.6751   3.8183  10.8535
# 3  20.5660  3.3755  7.4578  0.0095 -5.0659  14.0526  13.5010   8.7660
# 4  10.6048  2.9890  7.1437  5.1025 -3.2827  14.1013   8.9672   4.7276
#
#     var_15   var_16   var_17   var_18   var_19   var_20   var_21  var_22  \
# ...

# %%
submission_df = pd.DataFrame({
    'ID_code': test_df_id['ID_code'],
    'target': test_df['predicted_values']
})

# %%
submission_df.to_csv('submission6.csv', index=False)

# %%
submission_df.isna().sum()
# Out:
# ID_code    0
# target     0
# dtype: int64

# %%
#pip install pydot pydotplus

# %%
from IPython.display import Image, display
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

display(Image(filename='model_architecture.png', width=200, height=100))

# %% [markdown]
# # ******* This is the end! *******

# %% [markdown]
# ### PCA Dilemma: Reducing to Fewer Components While Retaining High Variance
#     PCA's primary goal is to reduce dimensionality while preserving as much data variance as possible. PCA works linearly, so if your data is highly non-linear, PCA struggles to effectively capture the variance in just a few components.
#     For non-linear data, PCA might not be the best tool. There are better methods for non-linear dimensionality reduction.

# %%
import umap
import matplotlib.pyplot as plt

reducer = umap.UMAP(n_components=10, random_state=42)

# Fit and transform data (assuming you have scaled data)
data = reducer.fit_transform(x)

umap_df = pd.DataFrame(data)
umap_df.columns = [f'UMAP_{i+1}' for i in range(umap_df.shape[1])]

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Assuming you have already scaled your data
tsne = TSNE(n_components=2, random_state=42)
tsne_result = tsne.fit_transform(scaled_df)

# Plotting the reduced 2D data
plt.figure(figsize=(8,6))
plt.scatter(tsne_result[:,0], tsne_result[:,1], c=target_labels)  # target_labels: color-coded by the label or class
plt.title('t-SNE results')
plt.show()
